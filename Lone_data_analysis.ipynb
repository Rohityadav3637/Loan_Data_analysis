# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/Loan 2.csv")

# %%
df.head()

# %%
df.shape
# Out:
# (30000, 24)

# %% [markdown]
# - Checking null values in Each column

# %%
df.isnull().sum()
# Out:
# Customer ID                       0
# Name                              0
# Gender                           53
# Age                               0
# Income (USD)                   4576
# Income Stability               1683
# Profession                        0
# Type of Employment             7270
# Location                          0
# Loan Amount Request (USD)         0
# Current Loan Expenses (USD)     172
# Expense Type 1                    0
# Expense Type 2                    0
# Dependents                     2493
# Credit Score                   1703
# No. of Defaults                   0
# Has Active Credit Card         1566
# Property ID                       0
# Property Age                   4850
# Property Type                     0
# Property Location               356
# Co-Applicant                      0
# Property Price                    0
# Loan Sanction Amount (USD)      340
# dtype: int64

# %%
k=df["Gender"].mode()[0]
# Filling the most frequent value in the "Gender" column using the mode() function

# %%
df["Gender"].fillna(value=k,inplace=True)
# Filled missing values in the "Gender" column with the most frequent gender value

# %%
df.dropna(subset="Income (USD)",axis=0,inplace=True)
# Drop rows with missing values in the "Income (USD)" column

# %%
incomeV=["High" if i>=df["Income (USD)"].mode()[0] else "Low" for i in df["Income (USD)"]]
df["Income Stability"].fillna(value=pd.Series(incomeV), inplace=True)

# %% [markdown]
# - Defined income stability categories based on income levels:
# - If an individual's income is equal to or above the mode income, they are categorized as "High".
# - Otherwise, they are categorized as "Low".
# - Filled missing values in the "Income Stability" column with the defined categories

# %%
null_check=df[df["Income Stability"].isnull()]

# %%
null_check
# Out:
#       Customer ID               Name Gender  Age  Income (USD)  \
# 25437      C-1631        Lavern Haan      F   18       3070.84
# 25442     C-15650   Alethia Barberio      M   52       5574.73
# 25459     C-25825  Magdalena Ratliff      F   28       1565.81
# 25465     C-20163   Vaughn Armistead      M   64       1716.79
# 25497      C-3163   Herbert Beckmann      F   62       1162.04
# ...           ...                ...    ...  ...           ...
# 29875       C-269     Jennell Geiser      F   64       1986.60
# 29876     C-16480   Adrianna Eriksen      F   19       1395.21
# 29911      C-4039     Xavier Mummert      F   36       1537.73
# 29914     C-10991      Herma Seawood      F   65       2941.17
# 29984     C-21758     Illa Hartgrove      F   59       1930.71
#
#       Income Stability            Profession Type of Employment    Location  \
# 25437              NaN  Commercial associate                NaN  Semi-Urban
# 25442              NaN  Commercial associate                NaN  Semi-Urban
# 25459              NaN               Working         Core staff  Semi-Urban
# 25465              NaN               Working           Laborers       Rural
# 25497              NaN               Working        Sales staff  Semi-Urban
# ...                ...                   ...                ...         ...
# 29875              NaN             Pensioner                NaN  Semi-Urban
# 29876              NaN               Working        Sales staff  Semi-Urban
# 29911              NaN               Working                NaN  Semi-Urban
# 29914              NaN             Pensioner                NaN       Rural
# 29984              NaN               Working           Laborers  Semi-Urban
#
#        Loan Amount Request (USD)  ...  Credit Score No. of Defaults  \
# 25437                   24347.18  ...        792.43               0
# 25442                   88174.85  ...        670.01               0
# 25459                   39872.50  ...        811.45               0
# 25465                   25968.80  ...        708.11               0
# 25497                   25300.42  ...        613.78               0
# ...                          ...  ...           ...             ...
# 29875                  199191.79  ...        825.34               0
# 29876                   84647.25  ...        724.49               0
# 29911                  140143.96  ...        815.09               0
# 29914                  102539.80  ...        764.71               0
# 29984                   63676.11  ...        729.75               0
#
#       Has Active Credit Card  Property ID  Property Age  Property Type  \
# 25437               Inactive           24       3070.84              1
# 25442                 Active          354       5574.73              3
# 25459               Inactive          966       1565.81              3
# 25465                 Active          569       1716.79              3
# 25497            Unpossessed          304       1162.04              3
# ...                      ...          ...           ...            ...
# 29875                 Active          947       1986.60              4
# 29876               Inactive          426       1395.21              1
# 29911                 Active          111       1537.73              3
# 29914                 Active          395       2941.17              4
# 29984                 Active          940       1930.71              2
#
#       Property Location  Co-Applicant  Property Price  \
# 25437        Semi-Urban             1        41133.35
# 25442             Rural             1       102096.13
# 25459             Rural             1        64463.79
# 25465             Rural             1        43018.79
# 25497             Rural             1        43115.88
# ...                 ...           ...             ...
# 29875             Urban             1       336032.01
# 29876             Urban             1       113083.42
# 29911             Urban             1       260180.01
# 29914             Rural             1       143365.18
# 29984             Rural             1        76539.32
#
#        Loan Sanction Amount (USD)
# 25437                    17043.03
# 25442                    57313.65
# 25459                    31898.00
# 25465                         NaN
# 25497                        0.00
# ...                           ...
# 29875                   159353.43
# 29876                    59253.08
# 29911                   105107.97
# 29914                    76904.85
# 29984                    44573.28
#
# [183 rows x 24 columns]

# %% [markdown]
# - Checked for null values in the "Income Stability" column.
# and we can see that we have some null values still left so we are going to drop those rows so that it dont affect later on

# %%
df.dropna(subset=["Income Stability"],axis=0,inplace=True)

# %% [markdown]
# - Filling Value of column "Type of Employment" 's null with 0

# %%
df["Type of Employment"].fillna(value=0,inplace=True)

# %% [markdown]
# - Filling null values in the "Current Loan Expenses (USD)" column with the "ffill" method

# %%
df["Current Loan Expenses (USD)"].fillna(value="ffill",inplace=True)

# %% [markdown]
# - Filling null values in the "Dependents" column with the rounded mean value

# %%
df["Dependents"].fillna(value=round(df["Dependents"].mean()),inplace=True)

# %% [markdown]
# - Filling null values in the "Credit Score" column with the mean value

# %%
df["Credit Score"].fillna(value=df["Credit Score"].mean(),inplace=True)

# %% [markdown]
# - Filling null values in the "Has Active Credit Card" column with the mode value

# %%
df['Has Active Credit Card'].fillna(value=df['Has Active Credit Card'].mode()[0], inplace=True)

# %% [markdown]
# - Filling null values in the "Property Age" column with the median value

# %%
df['Property Age'].fillna(value=df['Property Age'].median(), inplace=True)

# %% [markdown]
# - For the "Property Location" column, filling null values with the mode (most frequent value)

# %%
df['Property Location'].fillna(value=df['Property Location'].mode()[0], inplace=True)

# %% [markdown]
# - For the "Loan Sanction Amount (USD) " column, filling null values with the  forward fill value

# %%
df["Loan Sanction Amount (USD)"].fillna(value="ffill",inplace=True)

# %%
df.isnull().sum()#final check to ensure no null vlaues are left
# Out:
# Customer ID                    0
# Name                           0
# Gender                         0
# Age                            0
# Income (USD)                   0
# Income Stability               0
# Profession                     0
# Type of Employment             0
# Location                       0
# Loan Amount Request (USD)      0
# Current Loan Expenses (USD)    0
# Expense Type 1                 0
# Expense Type 2                 0
# Dependents                     0
# Credit Score                   0
# No. of Defaults                0
# Has Active Credit Card         0
# Property ID                    0
# Property Age                   0
# Property Type                  0
# Property Location              0
# Co-Applicant                   0
# Property Price                 0
# Loan Sanction Amount (USD)     0
# dtype: int64
